# %%
import random

def add(matrix):
        i = random.randint(0,3)
        j = random.randint(0,3)
        while (matrix[i][j] != 0):
            i = random.randint(0,3)
            j = random.randint(0,3)
        matrix [i][j] = 2
    

    
def start():
    matrix = []
    matrix = [[0] * 4 for i in range(4)]
    add(matrix)
    return matrix




def game_state_up_down(matrix):

    for i in range(4):
        for j in range(4):
            if matrix[i][j] == 2048:
                return 'win'
    for i in range(4): 
        for j in range(4): 
            if(matrix[i][j]== 0): 
                return 'not over'  
    for i in range(3): 
        for j in range(3): 
            if(matrix[i][j]== mat[i + 1][j]): 
                return 'not over'            
    for i in range(3): 
        if(matrix[i][3]== matrix[i + 1][3]): 
            return 'not over'
        
    return 'lose'


def game_state_left_right(matrix):


    for i in range(4):
        for j in range(4):
            if matrix[i][j] == 2048:
                return 'win'
    for i in range(4): 
        for j in range(4): 
            if(matrix[i][j]== 0): 
                return 'not over'
    for i in range(3): 
        for j in range(3): 
            if(matrix[i][j]== matrix[i][j + 1]): 
                return 'not over'
    for j in range(3): 
        if(matrix[3][j]== matrix[3][j + 1]): 
            return 'not over'
     
    return 'lose'
    

    
def game_state(matrix):
    
    if(game_state_left_right(matrix) == 'lose' and game_state_up_down == 'lose'):
        return 'lose'
    elif(game_state_left_right(matrix) == 'lose'):
        return 'not over'
    elif(game_state_up_down(matrix) == 'lose'):
        return 'not over'
    elif(game_state_left_right(matrix) == 'win' and game_state_up_down == 'win'):
        return 'win' 
    

def compress(matrix):
    is_changed = False
    new_matrix = []
    for i in range(4): 
        new_matrix.append([0] * 4)
    for i in range(4): 
        pos = 0
        
        for j in range(4): 
            if(matrix[i][j] != 0): 
                  
                new_matrix[i][pos] = matrix[i][j] 
                  
                if(j != pos): 
                    is_changed = True
                pos += 1
                
    return new_matrix, is_changed




def merge(matrix): 
      
    is_changed = False
      
    for i in range(4): 
        for j in range(3): 
  
            if(matrix[i][j] == matrix[i][j + 1] and matrix[i][j] != 0): 
   
                matrix[i][j] = matrix[i][j] * 2
                matrix[i][j + 1] = 0
  
                is_changed = True
  
    return matrix, is_changed 




def reverse(matrix): 
    new_matrix =[] 
    for i in range(4): 
        new_matrix.append([]) 
        for j in range(4): 
            new_matrix[i].append(matrix[i][3 - j]) 
    return new_matrix
  

def transpose(matrix): 
    new_matrix = [] 
    for i in range(4): 
        new_matrix.append([]) 
        for j in range(4): 
            new_matrix[i].append(matrix[j][i]) 
    return new_matrix 



def move_left(matrix): 
  
    new_matrix, is_changed1 = compress(matrix) 

    new_matrix, is_changed2 = merge(new_matrix) 

    is_changed = is_changed1 or is_changed2 
   
    new_matrix, temp = compress(new_matrix) 
  
    return new_matrix, is_changed 


def move_right(matrix): 
  
    new_matrix = reverse(matrix) 
  
    new_matrix, is_changed = move_left(new_matrix) 
  
    new_matrix = reverse(new_matrix) 
    return new_matrix, is_changed 


def move_up(matrix): 
  

    new_matrix = transpose(matrix) 
  

    new_matrix, is_changed = move_left(new_matrix) 
  

    new_matrix = transpose(new_matrix) 
    return new_matrix, is_changed 

def move_down(matrix): 
  
    new_matrix = transpose(matrix) 
  
    new_matrix, is_changed = move_right(new_matrix) 
    
    new_matrix = transpose(new_matrix) 
    return new_matrix, is_changed 



matrix = start() 

while(True): 
  
    x = input("Enter command W/S/A/D, Z to exit: ") 


    if(x == 'W' or x == 'w'): 
        matrix, flag = move_up(matrix) 
        status = game_state_up_down(matrix)
        if(status == 'lose'):
            print(status) 
            
        if(status == 'not over'): 
            add(matrix) 
        else: 
            break


    elif(x == 'S' or x == 's'): 
        matrix, flag = move_down(matrix) 
        status = game_state_up_down(matrix)
        if(status == 'lose'):
            print(status) 
        if(status == 'not over'): 
            add(matrix) 
        else: 
            break

    elif(x == 'A' or x == 'a'): 
        matrix, flag = move_left(matrix) 
        status = game_state_left_right(matrix)
        if(status == 'lose'):
            print(status) 
            
        if(status == 'not over'): 
            add(matrix) 
        else: 
            break

    elif(x == 'D' or x == 'd'): 
        matrix, flag = move_right(matrix) 
        status = game_state_left_right(matrix)
        if(status == 'lose'):
            print(status) 
            
        if(status == 'not over'): 
            add(matrix) 
        else: 
            break

    elif(x == 'z' or x == 'Z'): 
        import sys
        sys.exit()
    else: 
        print("Invalid Key Pressed") 
  
 
    for row in matrix:
        print (row)
# Out:
# Enter command W/S/A/D, Z to exit: a
# [2, 0, 0, 0]
# [0, 0, 0, 0]
# [0, 2, 0, 0]
# [0, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# [0, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: a
# [2, 0, 0, 0]
# [2, 0, 0, 0]
# [2, 0, 0, 0]
# [0, 0, 0, 2]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# [2, 0, 0, 2]
# Enter command W/S/A/D, Z to exit: a
# [2, 0, 0, 0]
# [2, 0, 2, 0]
# [2, 0, 0, 0]
# [4, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 0, 2]
# [0, 0, 2, 4]
# [0, 0, 0, 2]
# [0, 0, 0, 4]
# Enter command W/S/A/D, Z to exit: a
# [2, 0, 0, 0]
# [2, 4, 0, 0]
# [2, 0, 0, 2]
# [4, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 2, 2]
# [0, 0, 2, 4]
# [0, 0, 0, 4]
# [0, 0, 0, 4]
# Enter command W/S/A/D, Z to exit: as
# Invalid Key Pressed
# [0, 0, 2, 2]
# [0, 0, 2, 4]
# [0, 0, 0, 4]
# [0, 0, 0, 4]
# Enter command W/S/A/D, Z to exit: w
# [0, 2, 4, 2]
# [0, 0, 0, 8]
# [0, 0, 0, 4]
# [0, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 2, 4, 2]
# [0, 0, 0, 8]
# [0, 0, 0, 4]
# [0, 2, 0, 0]
# Enter command W/S/A/D, Z to exit: s
# [0, 0, 0, 0]
# [0, 0, 0, 2]
# [0, 0, 2, 8]
# [0, 4, 4, 4]
# Enter command W/S/A/D, Z to exit: a
# [0, 0, 0, 0]
# [2, 0, 0, 0]
# [2, 8, 0, 0]
# [8, 4, 2, 0]
# Enter command W/S/A/D, Z to exit: w
# [4, 8, 2, 0]
# [8, 4, 0, 0]
# [0, 0, 0, 0]
# [0, 0, 2, 0]
# Enter command W/S/A/D, Z to exit: s
# [0, 2, 0, 0]
# [0, 0, 0, 0]
# [4, 8, 0, 0]
# [8, 4, 4, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 0, 2]
# [0, 0, 0, 0]
# [2, 0, 4, 8]
# [0, 0, 8, 8]
# Enter command W/S/A/D, Z to exit: a
# [2, 0, 0, 0]
# [0, 0, 0, 0]
# [2, 4, 8, 0]
# [16, 2, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 0, 2]
# [0, 0, 0, 0]
# [0, 2, 4, 8]
# [2, 0, 16, 2]
# Enter command W/S/A/D, Z to exit: w
# [2, 2, 4, 2]
# [0, 0, 16, 8]
# [0, 2, 0, 2]
# [0, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: s
# [0, 0, 2, 0]
# [0, 0, 0, 2]
# [0, 0, 4, 8]
# [2, 4, 16, 2]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 2, 2]
# [0, 0, 0, 2]
# [0, 0, 4, 8]
# [2, 4, 16, 2]
# Enter command W/S/A/D, Z to exit: a
# [4, 2, 0, 0]
# [2, 0, 0, 0]
# [4, 8, 0, 0]
# [2, 4, 16, 2]
# Enter command W/S/A/D, Z to exit: s
# [4, 0, 0, 2]
# [2, 2, 0, 0]
# [4, 8, 0, 0]
# [2, 4, 16, 2]
# Enter command W/S/A/D, Z to exit: w
# [4, 2, 16, 4]
# [2, 8, 0, 0]
# [4, 4, 0, 0]
# [2, 0, 0, 2]
# Enter command W/S/A/D, Z to exit: s
# [4, 2, 0, 0]
# [2, 2, 0, 0]
# [4, 8, 0, 4]
# [2, 4, 16, 2]
# Enter command W/S/A/D, Z to exit: w
# [4, 4, 16, 4]
# [2, 8, 0, 2]
# [4, 4, 2, 0]
# [2, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: w
# [4, 4, 16, 4]
# [2, 8, 2, 2]
# [4, 4, 0, 2]
# [2, 0, 0, 0]
# Enter command W/S/A/D, Z to exit: w
# [4, 4, 16, 4]
# [2, 8, 2, 4]
# [4, 4, 0, 0]
# [2, 0, 0, 2]
# Enter command W/S/A/D, Z to exit: s
# [4, 0, 2, 0]
# [2, 4, 0, 0]
# [4, 8, 16, 8]
# [2, 4, 2, 2]
# Enter command W/S/A/D, Z to exit: d
# [0, 2, 4, 2]
# [0, 0, 2, 4]
# [4, 8, 16, 8]
# [0, 2, 4, 4]
# Enter command W/S/A/D, Z to exit: a
# [2, 4, 2, 2]
# [2, 4, 0, 0]
# [4, 8, 16, 8]
# [2, 8, 0, 0]
# Enter command W/S/A/D, Z to exit: d
# [2, 2, 4, 4]
# [0, 0, 2, 4]
# [4, 8, 16, 8]
# [0, 0, 2, 8]
# Enter command W/S/A/D, Z to exit: a
# [4, 8, 0, 0]
# [2, 4, 0, 0]
# [4, 8, 16, 8]
# [2, 8, 0, 2]
# Enter command W/S/A/D, Z to exit: d
# [0, 2, 4, 8]
# [0, 0, 2, 4]
# [4, 8, 16, 8]
# [0, 2, 8, 2]
# Enter command W/S/A/D, Z to exit: a
# [2, 4, 8, 2]
# [2, 4, 0, 0]
# [4, 8, 16, 8]
# [2, 8, 2, 0]
# Enter command W/S/A/D, Z to exit: d
# [2, 4, 8, 2]
# [2, 0, 2, 4]
# [4, 8, 16, 8]
# [0, 2, 8, 2]
# Enter command W/S/A/D, Z to exit: a
# [2, 4, 8, 2]
# [4, 4, 2, 0]
# [4, 8, 16, 8]
# [2, 8, 2, 0]
# Enter command W/S/A/D, Z to exit: d
# [2, 4, 8, 2]
# [0, 2, 8, 2]
# [4, 8, 16, 8]
# [0, 2, 8, 2]
# Enter command W/S/A/D, Z to exit: a
# [2, 4, 8, 2]
# [2, 8, 2, 2]
# [4, 8, 16, 8]
# [2, 8, 2, 0]
# Enter command W/S/A/D, Z to exit: w
# [4, 4, 8, 4]
# [4, 16, 2, 8]
# [2, 8, 16, 2]
# [0, 0, 2, 0]
# Enter command W/S/A/D, Z to exit: s
# [2, 0, 8, 0]
# [0, 4, 2, 4]
# [8, 16, 16, 8]
# [2, 8, 2, 2]
# Enter command W/S/A/D, Z to exit: w
# [2, 4, 8, 4]
# [8, 16, 2, 8]
# [2, 8, 16, 2]
# [2, 0, 2, 0]
# Enter command W/S/A/D, Z to exit: s
# [0, 0, 8, 2]
# [2, 4, 2, 4]
# [8, 16, 16, 8]
# [4, 8, 2, 2]
# Enter command W/S/A/D, Z to exit: a
# [8, 2, 0, 2]
# [2, 4, 2, 4]
# [8, 32, 8, 0]
# [4, 8, 4, 0]
# Enter command W/S/A/D, Z to exit: a
# [8, 4, 0, 0]
# [2, 4, 2, 4]
# [8, 32, 8, 2]
# [4, 8, 4, 0]
# Enter command W/S/A/D, Z to exit: d
# [0, 0, 8, 4]
# [2, 4, 2, 4]
# [8, 32, 8, 2]
# [2, 4, 8, 4]
# Enter command W/S/A/D, Z to exit: a
# [8, 4, 0, 2]
# [2, 4, 2, 4]
# [8, 32, 8, 2]
# [2, 4, 8, 4]
# Enter command W/S/A/D, Z to exit: d
# [2, 8, 4, 2]
# [2, 4, 2, 4]
# [8, 32, 8, 2]
# [2, 4, 8, 4]
# Enter command W/S/A/D, Z to exit: a
# lose
